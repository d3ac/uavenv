# %%
import numpy as np
from itertools import combinations

# %%
def generate_complex_gaussian(size): # 生成复数高斯噪声
    real_part = np.random.normal(0, 1, size)
    imag_part = np.random.normal(0, 1, size)
    return real_part + 1j*imag_part

def calc_fast_fading():
        h = generate_complex_gaussian(size=(1, 100000)) / np.sqrt(2) # 每一个slave对于所有的信道都先算出来
        return 20 * np.log10(np.abs(h)).reshape(-1)

a = calc_fast_fading()

# %%
import matplotlib.pyplot as plt

plt.hist(a, bins=100);

# %%
import numpy as np

def generate_rayleigh_fading_noise(size, sigma=1.0):
    noise = sigma * np.random.rayleigh(size=size)
    noise_db = 20 * np.log10(noise)
    return noise_db

# 测试一下
noise = generate_rayleigh_fading_noise(100000)
plt.hist(noise, bins=100);

# %%
def generate_rayleigh_fading():
    return 20 * np.log10(np.random.rayleigh(1/1.414, size=(100000)))
a = generate_rayleigh_fading()

# %%
plt.hist(a, bins=100);

# %%
30 * (10 ** -13)
# Out:
# 3e-12

# %%
A = 110.2
B = 33.8
C = 0
